# %% [markdown]
# # Assignment 3: Project Module and Madison City Budget

# %% [markdown]
# ## Your Information

# %% [markdown]
# At the start of each assignment, you will need to provide us your name and the name of the partner you worked with for this assignment (if you had one). Replace "First Last" with your first name and last name. Replace "None" with the first and last name of your partner if you had one for this assignment.

# %%
# MY NAME: First Last
# PARTNER: None

# %% [markdown]
# ## Imports

# %% [markdown]
# Every project will begin with some import statements. It's crucial that you run the cell below, otherwise we will not be able to grade your code and provide feedback to you.

# %%
# It is considered good coding practice to place all import statements at the top of the notebook.
import os
import student_grader
import importlib
import project_p3

# Set the LLM feedback language:
# 1=English, 2=Mandarin Chinese, 3=Spanish, 4=Hindi, 5=Portuguese,
# or use a string (e.g., "French")
student_grader.initialize(os.getcwd(), "p3", language=1)

# %% [markdown]
# Allowed imports
# * student_grader
# * os
# * importlib
# * project_p3

# %% [markdown]
# ## Project (29 Questions + 7 Functions)

# %% [markdown]
# <font color="red"> <strong>NOTE: If any of your previous answers are incorrect or incomplete, you must correct/complete them before proceeding. The grader may not accept later answers if earlier ones are still failing, even if those later answers are otherwise correct. </strong> </font>

# %% [markdown]
# ## Project Description:
#
# In this project, you will analyze the yearly budgets of seven different government agencies under the control of the City of Madison. The dataset we will analyze is obtained from the [City of Madison Finance Department](https://www.cityofmadison.com/finance/budget). In this project, we will be analyzing the **Adopted Budget** of a few select agencies between the years **2021** and **2025** (both years included).
#
# You'll get practice calling functions from the `project_p3` module (which we've provided) and practice writing your own functions.
#
# Before starting your work, make sure you have the `project_p3.py` and `madison_budget.csv` files in your `p3` folder.
#
#
# You can use the `help` function to learn about the various functions inside `project_p3.py`.
#
# You can also take a look at the code inside `project_p3.py`, if you are curious about how it works but you don't need to know how the specific functions work.

# %% [markdown]
# ## Dataset:
# The dataset you will be working with for this project is reproduced here:
#
# |id|agency|2021|2022|2023|2024|2025|
# |--|------|----|----|----|----|----|
# |5|Finance|3.744979|4.159134|4.645472|5.333063|6.090584|
# |19|Library|18.849564|19.066904|19.770825|20.748477|22.174898|
# |20|Fire|61.180396|63.742785|68.098376|70.292692|74.931653|
# |21|Police|82.794221|83.995148|86.917117|91.033353|96.131038|
# |23|Public Health|6.937629|7.48907|9.656299|10.193472|10.794522|
# |25|Parks|15.585153|15.535002|16.007257|16.616412|17.257403|
# |27|Metro Transit|8.511315|9.126564|2.009664|15.725|18.442237|
#
#
# This table lists seven different government agencies, and the budgets allotted to each of these agencies (in millions of dollars) between the years 2021 and 2025.
#
# The dataset is in the `madison_budget.csv` file which you downloaded.
#
# You can open the `madison_budget.csv` file to inspect this data.

# %% [markdown]
# ## Incremental Coding and Testing

# %% [markdown]
# You should always strive to do incremental coding, writing just a few lines of code at a time. You can call the `print` function to test intermediate step outputs. This will help you identify bugs as quickly as possible.
#
# We also recommend you do incremental testing: make sure to run the grader check as soon as you are done with a question. This will ensure that you haven't made a big mistake that might potentially impact the rest of your project.
#
# <font color="red"> <strong>NOTE: If any of your previous answers are incorrect or incomplete, you must correct/complete them before proceeding. The grader may not accept later answers if earlier ones are still failing, even if those later answers are otherwise correct. </strong> </font>

# %% [markdown]
# ### Initialization

# %% [markdown]
# The first step in this project is to initialize the `project_p3` module. This loads in the data from the CSV file which you will be using for this assignment.
#
# You must run the code below, otherwise the `project_p3` module will not be able to properly load the CSV data for this assignment.
#
# Please ignore the `importlib` line.

# %%
importlib.reload(project_p3)
project_p3.init("madison_budget.csv")

# %% [markdown]
# ### Getting familiar with the project_p3 module

# %% [markdown]
# #### Module contents

# %% [markdown]
# Before we can use the functions inside this module, we need to find out what functions are inside it. To do that, run the following cell:

# %%
dir(project_p3)

# %% [markdown]
# Recall that the variables listed that begin with an underscore (`_`) are private to that module. Thus, you don't need to worry about them.
#
# `csv` is a package that's built into Python. It's what our project_p3 module uses to load data from `.csv` files. Because our project_p3 module loads the CSV data for you, you don't need to worry about it either.
#
# The functions you need to understand are `dump`, `get_budget`, `get_id`, and `init`.

# %% [markdown]
# #### `project_p3.dump`

# %% [markdown]
# First, let's read the documentation for what this function does.

# %%
help(project_p3.dump)

# %% [markdown]
# Now, let's call it and see its output.

# %%
project_p3.dump()

# %% [markdown]
# From the output above, it looks like it has displayed the name of each agency in the `madison_budget.csv` file along with its ID and its budget for the years 2021-2025.
#
# You can call `project_p3.dump()` during this assignment to help you match agency names to IDs and what that agency's budget was for any given year.

# %% [markdown]
# ## Segment 1: `project_p3.get_id` and `project_p3.get_budget` (5 questions)

# %% [markdown]
# #### Project question 1

# %% [markdown]
# What is the `id` of the *Public Health* agency?

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code
# INCORRECT METHOD public_health_id = 23 => this is considered hardcoding
public_health_id = ...

public_health_id

# %%
student_grader.check("q1")

# %% [markdown]
# #### Project question 2

# %% [markdown]
# What is the `id` of the *Metro Transit* agency?

# %% [markdown]
# Points possible: 3.0

# %%
# replace the ... with your code

metro_transit_id = ...
metro_transit_id

# %%
student_grader.check("q2")

# %% [markdown]
# #### Project question 3

# %% [markdown]
# What are the IDs of all of the agencies in the dataset?
#
# Complete the code in the below cell and make sure to use the relevant ID variables for the rest of the project questions.

# %% [markdown]
# Points possible: 2.0

# %%
finance_id = project_p3.get_id("Finance")  # we have done this for you
library_id = project_p3.get_id("Library")  # we have done this for you

# replace each ... below to get the id for that agency
fire_id = ...
police_id = ...
parks_id = ...
metro_transit_id = ...
public_health_id = ...

# %%
student_grader.check("q3")

# %% [markdown]
# You should now have a good sense of how the `project_p3.get_id` function works. You will now move on to the `project_p3.get_budget` function. Read the documentation of this function, if you haven't already. Let us now call this function and see how it operates.
#
# **Note:** Recall that you can use `help(function_name)` to read the documentation of a function. Try reading the documentation for `get_budget` function using `help(project_p3.get_budget)`.
#
# If you want, you can create a **new** cell by clicking on the `+` button at the top of the notebook, and use that cell to read the documentation.

# %% [markdown]
# #### Project question 4

# %% [markdown]
# What was the budget of the *Fire* agency in 2025 (in millions of dollars)?
#
# Use the `project_p3.get_id` and `project_p3.get_budget` functions to directly retrieve the result.

# %% [markdown]
# Points possible: 3.0

# %%
# We have done this example for you, DO NOT EDIT this cell
fire_id = project_p3.get_id("Fire")
fire_budget_2025 = project_p3.get_budget(fire_id, 2025)
fire_budget_2025

# %%
student_grader.check("q4")

# %% [markdown]
# ### NOTE: Hardcoding
#
# You might be wondering why we can't simply use the *Fire* `id` value of *20* in our call to `project_p3.get_budget` instead of calling `project_p3.get_id` on the *Fire* agency to arrive at the same result. Using the `id` of *20* directly is considered **hardcoding**. Although the `id` was *20* in this case, you have no reason to expect that the dataset might not change in the future and that the IDs will not be updated. Furthermore, by **hardcoding** the `id` into your answer, you are limiting its ability to be used for other datasets, where *Fire* might have a **different** `id`.

# %% [markdown]
# #### Project question 5

# %% [markdown]
# What was the budget of the *Fire* agency in *2024*?

# %% [markdown]
# Points possible: 3.0

# %%
# Replace the ... with your code. Remember that you have already defined the
# variable `fire_id` in the question above. You should use that here.

fire_budget_2024 = ...
fire_budget_2024

# %%
student_grader.check("q5")

# %% [markdown]
# ### Segment 2: Calling and defining functions

# %% [markdown]
# #### Project function 1: `change_in_value_per_year`

# %% [markdown]
# **Note:** This function is a practice exercise that will help you design a similar function related to the dataset later in the project. The examples below use arbitrary values that are not directly related to the budget dataset, but the skills you practice here will be essential for analyzing budget trends.
#
# You will write a function to compute the average yearly change in value between two years.
#
# This function takes four parameters:
# - year1 (int): The first year.
# - value1 (int or float): The value associated with year1.
# - year2 (int): The second year (default: 2025).
# - value2 (int or float): The value associated with year2 (default: 6).
#
#
# The average yearly change can be calculated as the difference in values divided by the difference in years:
#
# $$
# average\_change\_per\_year = \frac{value2−value1}{year2−year1}
# $$
#
# It is not required that year2 is greater than year1—your function should work regardless of the order of the years.
#
# Example:
#
# Given the inputs:
# - year1 = 2022
# - value1 = 4
# - year2 = 2024
# - value2 = 0
#
# The output should be:
# $$
# average\_change\_per\_year = \frac{0−4}{2024−2022} = \frac{0−4}{2} = -2
# $$
#
# <font color="green">**Hint:** Think of this as computing the slope of a line passing through two points: (year1, value1) and (year2, value2). The difference between the years is the denominator, and the difference between the values is the numerator.<font>

# %% [markdown]
# Points possible: 6.0

# %%
# Replace the ... with your code


def change_in_value_per_year(
    year1, value1, year2=2025, value2=6
):  # DO NOT EDIT THIS LINE
    change_in_value = ... - ...
    num_years = ... - ...
    change_per_year = ... / ...
    return change_per_year

# %%
student_grader.check("change_in_value_per_year", should_get_llm_feedback=False)

# %% [markdown]
# #### Project question 6

# %% [markdown]
# What is the output of `change_in_value_per_year(2016, 30, 2020, 6)`?

# %% [markdown]
# Points possible: 5.0

# %%
# compute and store the answer in the variable 'change_per_year_2016_30_2020_6'
change_per_year_2016_30_2020_6 = ...

# display the variable 'change_per_year_2016_30_2020_6' here
change_per_year_2016_30_2020_6

# %%
student_grader.check("q6")

# %% [markdown]
# #### Project question 7

# %% [markdown]
# What is the output of `change_in_value_per_year(2018, 5, 2023, 25)`?

# %% [markdown]
# Points possible: 5.0

# %%
# compute and store the answer in the variable 'change_per_year_2018_5_2023_25'
change_per_year_2018_5_2023_25 = ...

# display the variable 'change_per_year_2018_5_2023_25' here
change_per_year_2018_5_2023_25

# %%
student_grader.check("q7")

# %% [markdown]
# ### Positional arguments, Keyword arguments, Default arguments
#
# If you look back at the definition of `change_in_value_per_year`,
#
# ```Python
# def change_in_value_per_year(year1, value1, year2=2025, value2=6):
# ```
#
# you'll notice that the parameters `year2` and `value2` were given **default** arguments with the name of the parameter followed by an equal sign and a value. This means that if you call that function without specifying values for `year2` and/or `value2`, those variables will take the value of `2025` and `6`, respectively. Thus, all of the following function calls are equivalent:
#
# ```Python
# # All positional arguments specified (order must match function header exactly)
# change_in_value_per_year(2020, 10, 2025, 6)
# ```
#
# ```Python
# # All named arguments specified
# change_in_value_per_year(year1=2020, value1=10, year2=2025, value2=6)
# ```
#
# ```Python
# # All named arguments specified (order does not matter among named arguments)
# change_in_value_per_year(value1=10, year2=2025, value2=6, year1=2020)
# ```
#
# ```Python
# # Named arguments are specified after positional arguments
# change_in_value_per_year(2020, 10, value2=6, year2=2025)
# ```
#
# ```Python
# # Only required positional arguments specified. Here year2 and value2 are assigned
# # based on their default values while year1 and value1 are set explicitly
# change_in_value_per_year(2020, 10)
# ```
#
# ```Python
# # Here only value2 is assigned based on its default value
# change_in_value_per_year(2020, 10, 2025)
# ```
#
# ```Python
# # Here only value2 is assigned based on its default value
# change_in_value_per_year(2020, 10, year2=2025)
# ```
#
# ```Python
# # Here only year2 is assigned based on its default value
# change_in_value_per_year(2020, 10, value2=6)
# ```

# %% [markdown]
# #### Project question 8

# %% [markdown]
# Find the change in value per year when `year1` is *2022*, `value1` is *21*, `year2` is *2016*, and `value2` is *6*
#
# <font color="green">**Hint:** Now it might be a good time to review the definitions of arguments above.<font>

# %% [markdown]
# Points possible: 5.0

# %%
# we have done this one for you
# note that the default argument for `value2` is used

change_per_year_2022_21_2016_6 = change_in_value_per_year(
    2022, 21, 2016
)  # Only 3 arguments are passed rather than 4 as `value2` uses its default value of 6
change_per_year_2022_21_2016_6

# %%
student_grader.check("q8")

# %% [markdown]
# #### Project question 9

# %% [markdown]
# Find the change in value per year when `year1` is *2015*, `value1` is *36*, `year2` is *2025*, and `value2` is *6*.
#
# Try using the default arguments for `year2` and `value2` by only specifying the first two arguments (`year1` and `value1`).

# %% [markdown]
# Points possible: 5.0

# %%
# replace the ... below with your code

change_per_year_2015_36_2025_6 = ...
change_per_year_2015_36_2025_6

# %%
student_grader.check("q9")

# %% [markdown]
# #### Project question 10

# %% [markdown]
# Find the change in value per year when `year1` is *2019*, `value1` is *2*, `year2` is *2025*, and `value2` is *20*.
#
# Here, try not to specify a value for `year2` and specify a value for `value2` using a **keyword argument**. Remember that positional arguments need to come first if you're using them.

# %% [markdown]
# Points possible: 4.0

# %%
# replace the ... with your code

change_per_year_2019_2_2025_20 = ...
change_per_year_2019_2_2025_20

# %%
student_grader.check("q10")

# %% [markdown]
# #### Project question 11

# %% [markdown]
# Find the change in value per year when `year1` is *2013*, `value1` is *25*, `year2` is *2025*, and `value2` is *1*.

# %% [markdown]
# Points possible: 4.0

# %%
# replace the ... with your code

change_per_year_2013_25_2025_1 = ...
change_per_year_2013_25_2025_1

# %%
student_grader.check("q11")

# %% [markdown]
# #### Project function 2: `year_max`

# %% [markdown]
# This function will compute the **maximum** budget for any one agency in a given `year`.
#
# It has already been written for you, so you do not have to modify it. You can directly call this function to answer the following questions.

# %% [markdown]
# Points possible: 2.0

# %%
# DO NOT EDIT THIS CELL
def year_max(year):
    finance_budget = project_p3.get_budget(finance_id, year)
    library_budget = project_p3.get_budget(library_id, year)
    fire_budget = project_p3.get_budget(fire_id, year)
    police_budget = project_p3.get_budget(police_id, year)
    public_health_budget = project_p3.get_budget(public_health_id, year)
    parks_budget = project_p3.get_budget(parks_id, year)
    metro_transit_budget = project_p3.get_budget(metro_transit_id, year)

    return max(
        finance_budget,
        library_budget,
        fire_budget,
        police_budget,
        public_health_budget,
        parks_budget,
        metro_transit_budget,
    )

# %%
student_grader.check("year_max")

# %% [markdown]
# #### Project question 12

# %% [markdown]
# What was the highest budget for *any* agency in the year *2025*?
#
# You **must** call the `year_max` function to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

max_budget_2025 = ...
max_budget_2025

# %%
student_grader.check("q12")

# %% [markdown]
# #### Project question 13

# %% [markdown]
# What was the highest budget for *any* agency in a single year in the period *2021-2023* (both years included)?
#
# Recall that we can use the built in `max` function to compute the maximum of some values. Look at the examples in the earlier section where you used the `max` function or the `year_max` function. The answer to this question is a single floating point number whose value is the highest budget allotted to an agency in a single year during these three years.
#
# You **must** invoke the `year_max` function in your answer to this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code
max_budget_2021 = ...
max_budget_2022 = ...
max_budget_2023 = ...

max_budget_2021_to_2023 = ...

max_budget_2021_to_2023

# %%
student_grader.check("q13")

# %% [markdown]
# #### Project function 3: `agency_min`

# %% [markdown]
# This function will compute the **lowest** budget allotted to the given `agency` during any year in the dataset (*2021-2025*).
#
# We'll help you get started with this function, but you need to fill in the rest of the function yourself.

# %% [markdown]
# Points possible: 2.0

# %%
# Replace the ... with your code


def agency_min(agency):

    agency_id = project_p3.get_id(agency)
    budget_2021 = project_p3.get_budget(agency_id, 2021)
    budget_2022 = project_p3.get_budget(agency_id, 2022)

    # get the budgets from other years below

    # use the min function to get the minimum across the five years
    min_budget_2021_to_2025 = ...

    return min_budget_2021_to_2025

# %%
student_grader.check("agency_min", should_get_llm_feedback=False)

# %% [markdown]
# #### Project question 14

# %% [markdown]
# What was the lowest budget allotted to the *Library* agency in a *single* year?
#
# You **must** call the `agency_min` function to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

min_budget_library = ...
min_budget_library

# %%
student_grader.check("q14")

# %% [markdown]
# #### Project question 15

# %% [markdown]
# What was the least budget allotted in any *single* year between the agencies *Fire* and *Police*?
#
# Recall that we can use the `min` function to compute the minimum of some values. The answer to this question is a single floating point number whose value is the lowest budget allotted during a single year during this entire period between *2021-2025* to any of the 2 agencies mentioned.
#
# You **must** invoke the `agency_min` function in your answer to this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

min_budget_fire_police = ...
min_budget_fire_police

# %%
student_grader.check("q15")

# %% [markdown]
# #### Project function 4: `agency_avg`

# %% [markdown]
# This function must compute the **average** budget for the given `agency` across the five years in the dataset (i.e. *2021 - 2025*).
#
# <font color="green">**Hint:** look at the `agency_min` function, since its structure will be very similar. However, instead of returning the minimum of `budget_2021`, `budget_2022`, etc., return the **average** of these by adding them together, then dividing by five. <font>
#
# The type of the *return value* **must** be `float`.

# %% [markdown]
# Points possible: 3.0

# %%
# replace the `pass` with your code


def agency_avg(agency):  # DO NOT EDIT this line
    # TODO here: replace the following with your code
    pass

# %%
student_grader.check("agency_avg", should_get_llm_feedback=False)

# %% [markdown]
# #### Project question 16

# %% [markdown]
# What was the average budget of the agency *Parks* between *2021* and *2025*?
#
# You **must** call the `agency_avg` function to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

parks_avg_budget = ...
parks_avg_budget

# %%
student_grader.check("q16")

# %% [markdown]
# #### Project question 17

# %% [markdown]
# What was the average budget of the *Public Health* agency between *2021* and *2025*?
#
# You **must** call the `agency_avg` function to answer this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

public_health_avg_budget = ...
public_health_avg_budget

# %%
student_grader.check("q17")

# %% [markdown]
# #### Project question 18

# %% [markdown]
# Relative to its **average**, how much **higher** or **lower** was the budget of the *Public Health* agency in *2025*?
#
# <font color="green">**Hint:** Compute the difference between the **average** budget and the budget in *2025* of *Public Health*. Your answer must be a **positive** number if the budget was **higher** in *2025* than on average. Your answer must be a **negative** number if the budget was **lower** in *2025* than on average.<font>
#
# Remember that you defined `public_health_avg_budget` in the question above. You should use that variable here.

# %% [markdown]
# Points possible: 2.0

# %%
# replace each ... with your code

public_health_2025_budget = ...
diff_public_health_2025_to_average = ...
diff_public_health_2025_to_average

# %%
student_grader.check("q18")

# %% [markdown]
# #### Project function 5: `year_budget`

# %% [markdown]
# This function must compute the **total** budget across all agencies for the given `year`. Specifically:
#
# 1. use the `project_p3.get_id` function to get the ID of each agency in the dataset (or could use the IDs that you extracted in Project Question 3).
#
# 2. For each agency, retrieve its budget for the specified `year` using the `project_p3.get_budget` function. Remember that `project_p3.get_budget` takes agency ID as an argument and not agency name.
#
# 3. Sum up all the budgets to get the total budget for that `year`.
#
# You can start from the following code snippet:

# %% [markdown]
# Points possible: 3.0

# %%
# Replace the `pass` with your code


def year_budget(year=2025):  # DO NOT EDIT THIS LINE
    # TODO here: replace the following with your code
    pass

# %%
student_grader.check("year_budget", should_get_llm_feedback=False)

# %% [markdown]
# #### Project question 19

# %% [markdown]
# What was the **total** budget across all seven agencies in *2025*?
#
# You **must** call the `year_budget` function to answer this question. Notice that the year in question is the same as the default argument (so your call to `year_budget` function does not need to pass any arguments).

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

total_budget_2025 = ...
total_budget_2025

# %%
student_grader.check("q19")

# %% [markdown]
# #### Project question 20

# %% [markdown]
# What was the **total** budget across all seven agencies across the years *2021-2023* (both years included)?
#
# You **must** invoke the `year_budget` function in your answer to this question.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code
total_budget_2021_to_2023 = ...
total_budget_2021_to_2023

# %%
student_grader.check("q20")

# %% [markdown]
# #### Project function 6: `change_budget_per_year`

# %% [markdown]
# This function should return the **average increase or decrease** in budget (must be **positive** if there's an **increase**, and **negative** if there’s a **decrease**) over the period from `start_year` to `end_year` for the given `agency` (agency name, not ID).
#
#
# $$
# budget\_change\_per\_year = \frac{budget_{year2}−budget_{year1}}{year2−year1}
# $$
#
# The type of the *return value* **must** be `float`.
#
# Recall that you created a similar function earlier in the project. You can start with the following code snippet (with the default arguments):

# %% [markdown]
# Points possible: 3.0

# %%
# replace the `pass` with your code


def change_budget_per_year(
    agency, start_year=2021, end_year=2025
):  # DO NOT EDIT THIS LINE
    # TODO here: replace the following with your code
    pass

# %%
student_grader.check("change_budget_per_year", should_get_llm_feedback=False)

# %% [markdown]
# #### Project question 21

# %% [markdown]
# How much has the budget of the *Parks* agency changed per year (on average) from *2021* to *2025*?
#
# Use the default arguments (your call to the `change_budget_per_year` function should not pass any more arguments than is necessary).

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

parks_average_change = ...
parks_average_change

# %%
student_grader.check("q21")

# %% [markdown]
# #### Project question 22

# %% [markdown]
# How much has the budget of the *Library* agency changed per year (on average) from *2022* to *2025*?
#
# Use the default argument for `end_year` (your call to the `change_budget_per_year` function should not pass any more arguments than is absolutely necessary).

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

library_average_change = ...
library_average_change

# %%
student_grader.check("q22")

# %% [markdown]
# #### Project question 23

# %% [markdown]
# How much has the budget of the *Police* agency changed per year (on average) from *2021* to *2023*?
#
# Use the default argument for `start_year` and specify `end_year` as a named argument. Your call to the `change_budget_per_year` function should not pass any more arguments than is absolutely necessary.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

police_average_change = ...
police_average_change

# %%
student_grader.check("q23")

# %% [markdown]
# #### Project question 24

# %% [markdown]
# How much has the budget of the *Finance* agency changed per year (on average) from *2022* to *2024*?

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

finance_average_change = ...
finance_average_change

# %%
student_grader.check("q24")

# %% [markdown]
# #### Project function 7: `extrapolate`

# %% [markdown]
# This function computes the **average** change per year from the data from `start_year` to `end_year` for `agency`. It then returns the **predicted budget** in `target_year`, assuming the budget continues increasing (or decreasing) by that same amount each year.
#
# The type of the *return value* **must** be `float`.
#
# Here's the formula written out:
#
# $$
# predicted\_budget = budget_{year2} + \frac{budget_{year2} - budget_{year1}}{year_2-year_1} * ({year_{target} - {year_2}})
# $$
#
# You can think of this formula as trying to find the y position ($predicted\_budget$) of a point given an x position (${year_{target} - {year_2}}$ years into the future), a slope (average budget change per year), and a y-intercept ($budget_{year2}$).
#
# Here's an example for where an agency had a budget of 1 in 2020 and a budget of 2 in 2022, where we want to predict what that agency's budget will be in 2030:
#
# $$
# predicted\_budget_{2030} =
# $$
# $$
# 2 + change\_budget\_per\_year(agency, 2020, 2022) * (2030 - 2022)
# $$
# $$
# = 2 + \frac{2 - 1}{2022 - 2020} * 8
# $$
# $$
# = 2 + \frac{1}{2} * 8
# $$
# $$
# = 2 + 4
# $$
# $$
# = 6
# $$
#
# You **must** call the `change_budget_per_year` function in the definition of `extrapolate`. **Do not** manually recompute the average change in budget.

# %% [markdown]
# Points possible: 3.0

# %%
# replace the `pass` with your code


def extrapolate(
    agency, target_year, start_year=2021, end_year=2025
):  # DO NOT EDIT this line
    # TODO here: replace the following with your code
    pass

# %%
student_grader.check("extrapolate", should_get_llm_feedback=False)

# %% [markdown]
# #### Project question 25

# %% [markdown]
# What is the **estimated** budget for the agency *Library* in *2026* based on the **average change** in budget per year for it between *2021* and *2025*?
#
# You **must** call the `extrapolate` function to answer this question. Use the default arguments for `start_year` and `end_year`. Your call to `extrapolate` should not pass any more arguments than is absolutely necessary.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

library_budget_2026 = ...
library_budget_2026

# %%
student_grader.check("q25")

# %% [markdown]
# #### Project question 26

# %% [markdown]
# What is the **estimated budget** for the *Parks* agency in *2030* based on the **average change** in budget per year for it between *2023* and *2025*?
#
# You **must** call the `extrapolate` function to answer this question. Use the default argument for `end_year` since its default value is 2025.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

parks_budget_2030 = ...
parks_budget_2030

# %%
student_grader.check("q26")

# %% [markdown]
# #### Project question 27

# %% [markdown]
# What is the **difference** between the **actual** budget in *2025* and **estimated budget** for the *Police* agency in *2025* based on the **average change** per year between *2021* and *2024*?
#
# <font color="green">**Hint:** The **difference** is calculated as the **actual budget** for the *Police* agency in *2025* **minus** the **estimated budget** based on the **average change** per year between *2021* and *2024*</font>
#
# You **must** invoke the `extrapolate` function in your answer to this question. A **positive** answer implies that the actual budget in *2025* is **higher**, while a negative answer implies that it is lower. Use the default argument for `start_year` since `2021` is its default value.

# %% [markdown]
# Points possible: 2.0

# %%
# replace each ... with your code


police_budget_2025_actual = ...
police_budget_2025_estimated = ...
police_diff_estimate_budget = ...
police_diff_estimate_budget

# %%
student_grader.check("q27")

# %% [markdown]
# #### Project question 28

# %% [markdown]
# What is the **difference** between the **actual** budget in *2025* and **estimated budget** for the *Metro Transit* agency in *2025* based on the **average change** per year between *2021* and *2023*?
#
# **Note:** This question uses a shorter time window (2021-2023) to demonstrate how extrapolation can be less reliable when based on limited data, especially when there are significant changes in later years.
#
# You **must** invoke the `extrapolate` function in your answer to this question. A **positive** answer implies that the actual budget in *2025* is **higher**, while a negative answer implies that it is lower.
#
# Use the default argument for `start_year` since `2021` is its default value.

# %% [markdown]
# Points possible: 2.0

# %%
# replace the ... with your code

metro_transit_diff_estimate_budget = ...
metro_transit_diff_estimate_budget

# %%
student_grader.check("q28")

# %% [markdown]
# #### Project question 29

# %% [markdown]
# The large discrepancy you observed in the previous question (Question 28) between the actual and estimated budget for Metro Transit suggests high variability in this agency's budget. Standard deviation is a statistical measure that quantifies this variability. What is the **standard deviation** of the budget allotted to the *Metro Transit* agency over the five years?
#
# **Instructions:** Compute the *population standard deviation* using this [article for reference](https://en.wikipedia.org/wiki/Standard_deviation#Population_standard_deviation_of_grades_of_eight_students).
#
# <font color="green">**Hints:**
# * <font color="green">You have 5 data points for this computation. After calculating the squared deviations of each data point from the mean, you will find their average by summing up these squared deviations and dividing by 5.
#
# * <font color="green">Use the `agency_avg` function to find the average budget for this agency across the 5 years.
#
# * <font color="green">You can find the square root of any number by raising it to the exponent `0.5`. In other words, the square root of `2` can be computed as `2**(0.5)`.<font>

# %% [markdown]
# Points possible: 3.0

# %%
# Add variables here as needed, then replace the ... with your code

metro_transit_budget_std_dev = ...
metro_transit_budget_std_dev

# %%
student_grader.check("q29", should_get_llm_feedback=False)

# %% [markdown]
# ## Submission and Grading

# %% [markdown]
# **Congrats on finishing p3!**
#
# Now, please submit your `p3.ipynb` file on Gradescope. This will follow the exact same process you used when submitting earlier projects.
#
# Please post on Piazza if you run into any issues when uploading your notebook to gradescope.
